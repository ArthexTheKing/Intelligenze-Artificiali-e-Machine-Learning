# %%
from random import random, sample
from math import exp

# %% [markdown]
# ## Funzioni Ausiliare del problema delle n Regine

# %%
def genera_stato_iniziale(nRegine: int):
    return [i for i in range(nRegine)]

# %%
def funzione_succesione(stato: list):
    next = stato.copy()
    regina1, regina2 = sample(range(len(stato)), 2)
    next[regina1], next[regina2] = next[regina2], next[regina1]
    return next

# %%
def funzione_valutazione(stato: list):
    dimensione = len(stato)

    scacchiera = [[0] * dimensione for _ in range(dimensione)]
    
    for i in range(dimensione):
        scacchiera[stato[i]][i] = 'Q'
        
    dx = [1, -1, -1, 1]
    dy = [1, 1, -1, -1]
    
    conflitti = 0

    for i in range(dimensione):       
        x, y = stato[i], i
             
        for j in range(4):
            tempX, tempY = x, y
            while True:
                tempX += dx[j]
                tempY += dy[j]
                if (tempX < 0) or (tempX >= dimensione) or (tempY < 0) or (tempY >= dimensione):
                    break                      
                if scacchiera[tempX][tempY] == 'Q':
                    conflitti += 1

    return conflitti

# %%
def stampa_scacchiera(soluzione):
    dimensione = len(soluzione)

    scacchiera = [[' . '] * dimensione for _ in range(dimensione)] 

    for i in range(dimensione):
        scacchiera[soluzione[i]][i] = ' Q '
    
    print("SCACCHIERA")
    for x in range(dimensione):
        for y in range(dimensione):
            print(scacchiera[x][y], end=''),
        print("\n")

# %% [markdown]
# ## Iperparametri

# %%
N_REGINE = 20

TEMPERATURA_INIZIALE = 50
TEMPERATURA_FINALE = 0.2
FATTORE_RIDUZIONE = 0.99
STEP = 100

# %% [markdown]
# ## Algoritmo Simulated Annealing

# %%
def simulated_annealing_nRegine():

    stato_attuale = genera_stato_iniziale(N_REGINE)
    stato_attuale_val = funzione_valutazione(stato_attuale)

    stato_migliore = stato_attuale
    stato_migliore_val = stato_attuale_val

    temperatura_attuale = TEMPERATURA_INIZIALE

    step_totali = 0

    while stato_migliore_val != 0 and temperatura_attuale > TEMPERATURA_FINALE:

        for _ in range(STEP):

            stato_successivo = funzione_succesione(stato_attuale)
            stato_successivo_val = funzione_valutazione(stato_successivo)

            step_totali += 1

            delta_val = stato_successivo_val - stato_attuale_val

            usa_stato_successivo = False

            if delta_val < 0:
                usa_stato_successivo = True
            else:
                if random() < exp(- delta_val / temperatura_attuale):
                    usa_stato_successivo = True
            
            if usa_stato_successivo:

                stato_attuale = stato_successivo
                stato_attuale_val = stato_successivo_val

                if stato_attuale_val < stato_migliore_val:

                    stato_migliore = stato_attuale
                    stato_migliore_val = stato_attuale_val
    
        print(f'Temperatura: {temperatura_attuale}, Collisioni: {stato_migliore_val}')

        temperatura_attuale *= FATTORE_RIDUZIONE
    
    return stato_migliore, step_totali

# %%
soluzione, step = simulated_annealing_nRegine()
# Out:
# Temperatura: 50, Collisioni: 14
# Temperatura: 49.5, Collisioni: 10
# Temperatura: 49.005, Collisioni: 10
# Temperatura: 48.51495, Collisioni: 10
# Temperatura: 48.0298005, Collisioni: 10
# Temperatura: 47.549502495, Collisioni: 10
# Temperatura: 47.07400747005, Collisioni: 10
# Temperatura: 46.6032673953495, Collisioni: 10
# Temperatura: 46.137234721396005, Collisioni: 10
# Temperatura: 45.675862374182046, Collisioni: 10
# Temperatura: 45.219103750440226, Collisioni: 10
# Temperatura: 44.76691271293582, Collisioni: 10
# Temperatura: 44.31924358580646, Collisioni: 10
# Temperatura: 43.876051149948395, Collisioni: 10
# Temperatura: 43.437290638448914, Collisioni: 10
# Temperatura: 43.002917732064425, Collisioni: 10
# Temperatura: 42.57288855474378, Collisioni: 8
# Temperatura: 42.14715966919634, Collisioni: 8
# Temperatura: 41.725688072504376, Collisioni: 8
# Temperatura: 41.308431191779334, Collisioni: 8
# Temperatura: 40.89534687986154, Collisioni: 8
# Temperatura: 40.48639341106293, Collisioni: 8
# Temperatura: 40.0815294769523, Collisioni: 8
# Temperatura: 39.680714182182776, Collisioni: 8
# Temperatura: 39.283907040360944, Collisioni: 8
# Temperatura: 38.891067969957334, Collisioni: 8
# Temperatura: 38.50215729025776, Collisioni: 8
# Temperatura: 38.11713571735518, Collisioni: 8
# Temperatura: 37.73596436018163, Collisioni: 8
# Temperatura: 37.35860471657982, Collisioni: 8
# Temperatura: 36.98501866941402, Collisioni: 8
# Temperatura: 36.61516848271988, Collisioni: 8
# Temperatura: 36.24901679789268, Collisioni: 8
# Temperatura: 35.88652662991375, Collisioni: 8
# Temperatura: 35.52766136361461, Collisioni: 8
# Temperatura: 35.17238474997846, Collisioni: 8
# Temperatura: 34.82066090247868, Collisioni: 8
# Temperatura: 34.47245429345389, Collisioni: 8
# Temperatura: 34.12772975051936, Collisioni: 8
# Temperatura: 33.786452453014164, Collisioni: 8
# Temperatura: 33.448587928484024, Collisioni: 8
# Temperatura: 33.11410204919918, Collisioni: 8
# Temperatura: 32.78296102870719, Collisioni: 8
# Temperatura: 32.455131418420116, Collisioni: 8
# Temperatura: 32.13058010423592, Collisioni: 8
# Temperatura: 31.809274303193558, Collisioni: 8
# Temperatura: 31.49118156016162, Collisioni: 8
# Temperatura: 31.176269744560006, Collisioni: 8
# Temperatura: 30.864507047114405, Collisioni: 6
# Temperatura: 30.55586197664326, Collisioni: 6
# Temperatura: 30.250303356876827, Collisioni: 6
# Temperatura: 29.94780032330806, Collisioni: 6
# Temperatura: 29.64832232007498, Collisioni: 6
# Temperatura: 29.35183909687423, Collisioni: 6
# Temperatura: 29.058320705905487, Collisioni: 6
# Temperatura: 28.767737498846433, Collisioni: 6
# Temperatura: 28.480060123857967, Collisioni: 6
# Temperatura: 28.195259522619388, Collisioni: 6
# Temperatura: 27.913306927393194, Collisioni: 6
# Temperatura: 27.63417385811926, Collisioni: 6
# Temperatura: 27.35783211953807, Collisioni: 6
# Temperatura: 27.08425379834269, Collisioni: 6
# Temperatura: 26.813411260359263, Collisioni: 6
# Temperatura: 26.54527714775567, Collisioni: 6
# Temperatura: 26.279824376278114, Collisioni: 6
# Temperatura: 26.017026132515333, Collisioni: 6
# Temperatura: 25.75685587119018, Collisioni: 6
# Temperatura: 25.499287312478277, Collisioni: 6
# Temperatura: 25.244294439353492, Collisioni: 6
# Temperatura: 24.991851494959956, Collisioni: 6
# Temperatura: 24.741932980010358, Collisioni: 6
# Temperatura: 24.494513650210255, Collisioni: 6
# Temperatura: 24.24956851370815, Collisioni: 6
# Temperatura: 24.00707282857107, Collisioni: 6
# Temperatura: 23.767002100285357, Collisioni: 6
# Temperatura: 23.529332079282504, Collisioni: 6
# Temperatura: 23.29403875848968, Collisioni: 6
# Temperatura: 23.061098370904784, Collisioni: 6
# Temperatura: 22.830487387195735, Collisioni: 6
# Temperatura: 22.602182513323775, Collisioni: 6
# Temperatura: 22.376160688190538, Collisioni: 6
# Temperatura: 22.152399081308634, Collisioni: 6
# Temperatura: 21.930875090495547, Collisioni: 6
# Temperatura: 21.711566339590593, Collisioni: 6
# Temperatura: 21.49445067619469, Collisioni: 6
# Temperatura: 21.279506169432743, Collisioni: 6
# Temperatura: 21.066711107738417, Collisioni: 6
# Temperatura: 20.856043996661032, Collisioni: 6
# Temperatura: 20.64748355669442, Collisioni: 6
# Temperatura: 20.441008721127478, Collisioni: 6
# Temperatura: 20.236598633916202, Collisioni: 6
# Temperatura: 20.03423264757704, Collisioni: 6
# Temperatura: 19.83389032110127, Collisioni: 6
# Temperatura: 19.635551417890255, Collisioni: 6
# Temperatura: 19.43919590371135, Collisioni: 6
# Temperatura: 19.24480394467424, Collisioni: 6
# Temperatura: 19.052355905227497, Collisioni: 6
# Temperatura: 18.861832346175223, Collisioni: 6
# Temperatura: 18.67321402271347, Collisioni: 6
# Temperatura: 18.486481882486334, Collisioni: 6
# Temperatura: 18.30161706366147, Collisioni: 6
# Temperatura: 18.118600893024855, Collisioni: 6
# Temperatura: 17.937414884094608, Collisioni: 6
# Temperatura: 17.758040735253662, Collisioni: 6
# Temperatura: 17.580460327901125, Collisioni: 6
# Temperatura: 17.404655724622113, Collisioni: 6
# Temperatura: 17.230609167375892, Collisioni: 6
# Temperatura: 17.058303075702135, Collisioni: 6
# Temperatura: 16.887720044945112, Collisioni: 6
# Temperatura: 16.71884284449566, Collisioni: 6
# Temperatura: 16.551654416050706, Collisioni: 6
# Temperatura: 16.3861378718902, Collisioni: 6
# Temperatura: 16.222276493171297, Collisioni: 6
# Temperatura: 16.060053728239584, Collisioni: 6
# Temperatura: 15.899453190957187, Collisioni: 6
# Temperatura: 15.740458659047615, Collisioni: 6
# Temperatura: 15.58305407245714, Collisioni: 6
# Temperatura: 15.427223531732569, Collisioni: 6
# Temperatura: 15.272951296415243, Collisioni: 6
# Temperatura: 15.120221783451091, Collisioni: 6
# Temperatura: 14.96901956561658, Collisioni: 6
# Temperatura: 14.819329369960414, Collisioni: 6
# Temperatura: 14.67113607626081, Collisioni: 6
# Temperatura: 14.524424715498201, Collisioni: 6
# Temperatura: 14.379180468343218, Collisioni: 6
# Temperatura: 14.235388663659785, Collisioni: 6
# Temperatura: 14.093034777023187, Collisioni: 6
# Temperatura: 13.952104429252955, Collisioni: 6
# Temperatura: 13.812583384960426, Collisioni: 6
# Temperatura: 13.674457551110821, Collisioni: 6
# Temperatura: 13.537712975599712, Collisioni: 6
# Temperatura: 13.402335845843714, Collisioni: 6
# Temperatura: 13.268312487385277, Collisioni: 6
# Temperatura: 13.135629362511423, Collisioni: 6
# Temperatura: 13.00427306888631, Collisioni: 6
# Temperatura: 12.874230338197446, Collisioni: 6
# Temperatura: 12.745488034815471, Collisioni: 6
# Temperatura: 12.618033154467316, Collisioni: 6
# Temperatura: 12.491852822922642, Collisioni: 6
# Temperatura: 12.366934294693415, Collisioni: 6
# Temperatura: 12.24326495174648, Collisioni: 6
# Temperatura: 12.120832302229015, Collisioni: 6
# Temperatura: 11.999623979206724, Collisioni: 6
# Temperatura: 11.879627739414657, Collisioni: 6
# Temperatura: 11.76083146202051, Collisioni: 6
# Temperatura: 11.643223147400304, Collisioni: 6
# Temperatura: 11.526790915926302, Collisioni: 6
# Temperatura: 11.41152300676704, Collisioni: 6
# Temperatura: 11.29740777669937, Collisioni: 6
# Temperatura: 11.184433698932375, Collisioni: 6
# Temperatura: 11.072589361943052, Collisioni: 6
# Temperatura: 10.961863468323621, Collisioni: 6
# Temperatura: 10.852244833640384, Collisioni: 6
# Temperatura: 10.74372238530398, Collisioni: 6
# Temperatura: 10.63628516145094, Collisioni: 6
# Temperatura: 10.529922309836431, Collisioni: 6
# Temperatura: 10.424623086738066, Collisioni: 6
# Temperatura: 10.320376855870686, Collisioni: 6
# Temperatura: 10.217173087311979, Collisioni: 6
# Temperatura: 10.115001356438858, Collisioni: 6
# Temperatura: 10.013851342874469, Collisioni: 6
# Temperatura: 9.913712829445725, Collisioni: 6
# Temperatura: 9.814575701151268, Collisioni: 6
# Temperatura: 9.716429944139755, Collisioni: 6
# Temperatura: 9.619265644698357, Collisioni: 6
# Temperatura: 9.523072988251373, Collisioni: 6
# Temperatura: 9.427842258368859, Collisioni: 6
# Temperatura: 9.33356383578517, Collisioni: 6
# Temperatura: 9.240228197427319, Collisioni: 6
# Temperatura: 9.147825915453046, Collisioni: 6
# Temperatura: 9.056347656298515, Collisioni: 6
# Temperatura: 8.965784179735529, Collisioni: 6
# Temperatura: 8.876126337938173, Collisioni: 6
# Temperatura: 8.78736507455879, Collisioni: 6
# Temperatura: 8.699491423813203, Collisioni: 6
# Temperatura: 8.61249650957507, Collisioni: 6
# Temperatura: 8.52637154447932, Collisioni: 6
# Temperatura: 8.441107829034527, Collisioni: 6
# Temperatura: 8.356696750744181, Collisioni: 6
# Temperatura: 8.273129783236739, Collisioni: 6
# Temperatura: 8.190398485404371, Collisioni: 6
# Temperatura: 8.108494500550327, Collisioni: 6
# Temperatura: 8.027409555544823, Collisioni: 6
# Temperatura: 7.947135459989375, Collisioni: 6
# Temperatura: 7.867664105389481, Collisioni: 6
# Temperatura: 7.788987464335586, Collisioni: 6
# Temperatura: 7.71109758969223, Collisioni: 6
# Temperatura: 7.633986613795307, Collisioni: 6
# Temperatura: 7.557646747657354, Collisioni: 6
# Temperatura: 7.48207028018078, Collisioni: 6
# Temperatura: 7.407249577378972, Collisioni: 6
# Temperatura: 7.333177081605182, Collisioni: 6
# Temperatura: 7.259845310789131, Collisioni: 6
# Temperatura: 7.187246857681239, Collisioni: 6
# Temperatura: 7.115374389104426, Collisioni: 6
# Temperatura: 7.0442206452133815, Collisioni: 6
# Temperatura: 6.973778438761248, Collisioni: 6
# Temperatura: 6.9040406543736355, Collisioni: 6
# Temperatura: 6.835000247829899, Collisioni: 6
# Temperatura: 6.7666502453516, Collisioni: 6
# Temperatura: 6.698983742898084, Collisioni: 6
# Temperatura: 6.631993905469103, Collisioni: 6
# Temperatura: 6.565673966414412, Collisioni: 6
# Temperatura: 6.500017226750268, Collisioni: 6
# Temperatura: 6.435017054482765, Collisioni: 6
# Temperatura: 6.370666883937938, Collisioni: 6
# Temperatura: 6.306960215098559, Collisioni: 6
# Temperatura: 6.243890612947573, Collisioni: 6
# Temperatura: 6.181451706818097, Collisioni: 6
# Temperatura: 6.119637189749916, Collisioni: 6
# Temperatura: 6.058440817852417, Collisioni: 6
# Temperatura: 5.997856409673893, Collisioni: 6
# Temperatura: 5.9378778455771535, Collisioni: 6
# Temperatura: 5.878499067121382, Collisioni: 6
# Temperatura: 5.819714076450168, Collisioni: 6
# Temperatura: 5.761516935685666, Collisioni: 6
# Temperatura: 5.703901766328809, Collisioni: 6
# Temperatura: 5.646862748665521, Collisioni: 6
# Temperatura: 5.590394121178866, Collisioni: 6
# Temperatura: 5.534490179967078, Collisioni: 6
# Temperatura: 5.479145278167406, Collisioni: 6
# Temperatura: 5.424353825385732, Collisioni: 6
# Temperatura: 5.370110287131875, Collisioni: 6
# Temperatura: 5.316409184260556, Collisioni: 6
# Temperatura: 5.263245092417951, Collisioni: 6
# Temperatura: 5.210612641493771, Collisioni: 6
# Temperatura: 5.158506515078834, Collisioni: 6
# Temperatura: 5.106921449928046, Collisioni: 6
# Temperatura: 5.055852235428765, Collisioni: 6
# Temperatura: 5.005293713074478, Collisioni: 6
# Temperatura: 4.955240775943733, Collisioni: 6
# Temperatura: 4.905688368184296, Collisioni: 6
# Temperatura: 4.856631484502453, Collisioni: 6
# Temperatura: 4.808065169657429, Collisioni: 6
# Temperatura: 4.759984517960854, Collisioni: 6
# Temperatura: 4.712384672781245, Collisioni: 6
# Temperatura: 4.665260826053433, Collisioni: 6
# Temperatura: 4.618608217792898, Collisioni: 6
# Temperatura: 4.5724221356149695, Collisioni: 6
# Temperatura: 4.526697914258819, Collisioni: 6
# Temperatura: 4.481430935116231, Collisioni: 6
# Temperatura: 4.436616625765069, Collisioni: 6
# Temperatura: 4.3922504595074185, Collisioni: 6
# Temperatura: 4.348327954912344, Collisioni: 6
# Temperatura: 4.304844675363221, Collisioni: 6
# Temperatura: 4.2617962286095885, Collisioni: 6
# Temperatura: 4.2191782663234925, Collisioni: 6
# Temperatura: 4.176986483660258, Collisioni: 6
# Temperatura: 4.135216618823655, Collisioni: 6
# Temperatura: 4.093864452635419, Collisioni: 6
# Temperatura: 4.052925808109064, Collisioni: 6
# Temperatura: 4.012396550027973, Collisioni: 6
# Temperatura: 3.9722725845276936, Collisioni: 6
# Temperatura: 3.9325498586824166, Collisioni: 6
# Temperatura: 3.8932243600955925, Collisioni: 6
# Temperatura: 3.8542921164946367, Collisioni: 6
# Temperatura: 3.81574919532969, Collisioni: 6
# Temperatura: 3.7775917033763933, Collisioni: 6
# Temperatura: 3.7398157863426293, Collisioni: 6
# Temperatura: 3.702417628479203, Collisioni: 6
# Temperatura: 3.6653934521944107, Collisioni: 6
# Temperatura: 3.6287395176724666, Collisioni: 6
# Temperatura: 3.5924521224957418, Collisioni: 6
# Temperatura: 3.5565276012707843, Collisioni: 4
# Temperatura: 3.5209623252580764, Collisioni: 4
# Temperatura: 3.4857527020054957, Collisioni: 4
# Temperatura: 3.450895174985441, Collisioni: 4
# Temperatura: 3.4163862232355866, Collisioni: 4
# Temperatura: 3.382222361003231, Collisioni: 4
# Temperatura: 3.3484001373931984, Collisioni: 4
# Temperatura: 3.3149161360192663, Collisioni: 4
# Temperatura: 3.2817669746590736, Collisioni: 4
# Temperatura: 3.248949304912483, Collisioni: 4
# Temperatura: 3.216459811863358, Collisioni: 4
# Temperatura: 3.1842952137447242, Collisioni: 4
# Temperatura: 3.152452261607277, Collisioni: 4
# Temperatura: 3.1209277389912042, Collisioni: 4
# Temperatura: 3.0897184616012923, Collisioni: 4
# Temperatura: 3.058821276985279, Collisioni: 4
# Temperatura: 3.0282330642154265, Collisioni: 4
# Temperatura: 2.9979507335732722, Collisioni: 4
# Temperatura: 2.9679712262375393, Collisioni: 4
# Temperatura: 2.9382915139751637, Collisioni: 4
# Temperatura: 2.908908598835412, Collisioni: 4
# Temperatura: 2.879819512847058, Collisioni: 4
# Temperatura: 2.8510213177185872, Collisioni: 2
# Temperatura: 2.8225111045414013, Collisioni: 2
# Temperatura: 2.794285993495987, Collisioni: 2
# Temperatura: 2.766343133561027, Collisioni: 2
# Temperatura: 2.738679702225417, Collisioni: 2
# Temperatura: 2.7112929052031625, Collisioni: 2
# Temperatura: 2.684179976151131, Collisioni: 2
# Temperatura: 2.6573381763896196, Collisioni: 2
# Temperatura: 2.6307647946257235, Collisioni: 2
# Temperatura: 2.6044571466794664, Collisioni: 2
# Temperatura: 2.578412575212672, Collisioni: 2
# Temperatura: 2.552628449460545, Collisioni: 2
# Temperatura: 2.5271021649659398, Collisioni: 2
# Temperatura: 2.5018311433162803, Collisioni: 2
# Temperatura: 2.4768128318831173, Collisioni: 2
# Temperatura: 2.4520447035642863, Collisioni: 2
# Temperatura: 2.4275242565286432, Collisioni: 2
# Temperatura: 2.403249013963357, Collisioni: 2
# Temperatura: 2.3792165238237235, Collisioni: 2
# Temperatura: 2.3554243585854864, Collisioni: 2
# Temperatura: 2.3318701149996315, Collisioni: 2
# Temperatura: 2.308551413849635, Collisioni: 2
# Temperatura: 2.285465899711139, Collisioni: 2
# Temperatura: 2.2626112407140275, Collisioni: 2
# Temperatura: 2.2399851283068872, Collisioni: 2
# Temperatura: 2.2175852770238182, Collisioni: 2
# Temperatura: 2.19540942425358, Collisioni: 2
# Temperatura: 2.173455330011044, Collisioni: 2
# Temperatura: 2.1517207767109334, Collisioni: 2
# Temperatura: 2.130203568943824, Collisioni: 2
# Temperatura: 2.1089015332543855, Collisioni: 2
# Temperatura: 2.0878125179218414, Collisioni: 2
# Temperatura: 2.066934392742623, Collisioni: 2
# Temperatura: 2.0462650488151968, Collisioni: 2
# Temperatura: 2.025802398327045, Collisioni: 2
# Temperatura: 2.005544374343774, Collisioni: 2
# Temperatura: 1.9854889306003365, Collisioni: 2
# Temperatura: 1.9656340412943332, Collisioni: 2
# Temperatura: 1.9459777008813899, Collisioni: 2
# Temperatura: 1.926517923872576, Collisioni: 2
# Temperatura: 1.9072527446338503, Collisioni: 2
# Temperatura: 1.8881802171875117, Collisioni: 2
# Temperatura: 1.8692984150156366, Collisioni: 2
# Temperatura: 1.8506054308654802, Collisioni: 2
# Temperatura: 1.8320993765568254, Collisioni: 2
# Temperatura: 1.8137783827912572, Collisioni: 2
# Temperatura: 1.7956405989633446, Collisioni: 2
# Temperatura: 1.777684192973711, Collisioni: 2
# Temperatura: 1.759907351043974, Collisioni: 2
# Temperatura: 1.7423082775335343, Collisioni: 2
# Temperatura: 1.724885194758199, Collisioni: 2
# Temperatura: 1.707636342810617, Collisioni: 2
# Temperatura: 1.6905599793825108, Collisioni: 2
# Temperatura: 1.6736543795886856, Collisioni: 2
# Temperatura: 1.6569178357927987, Collisioni: 2
# Temperatura: 1.6403486574348707, Collisioni: 2
# Temperatura: 1.623945170860522, Collisioni: 2
# Temperatura: 1.6077057191519166, Collisioni: 2
# Temperatura: 1.5916286619603974, Collisioni: 2
# Temperatura: 1.5757123753407933, Collisioni: 2
# Temperatura: 1.5599552515873853, Collisioni: 2
# Temperatura: 1.5443556990715115, Collisioni: 2
# Temperatura: 1.5289121420807963, Collisioni: 2
# Temperatura: 1.5136230206599883, Collisioni: 2
# Temperatura: 1.4984867904533885, Collisioni: 2
# Temperatura: 1.4835019225488546, Collisioni: 2
# Temperatura: 1.4686669033233661, Collisioni: 2
# Temperatura: 1.4539802342901325, Collisioni: 2
# Temperatura: 1.4394404319472311, Collisioni: 2
# Temperatura: 1.4250460276277588, Collisioni: 2
# Temperatura: 1.4107955673514812, Collisioni: 0

# %%
step
# Out:
# 35600

# %%
stampa_scacchiera(soluzione)
# Out:
# SCACCHIERA
#  .  .  .  .  .  .  .  .  .  Q  .  .  .  .  .  .  .  .  .  .
#
#  .  .  .  .  .  .  .  Q  .  .  .  .  .  .  .  .  .  .  .  .
#
#  .  .  .  .  Q  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Q
#
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Q  .  .
#
#  .  .  .  .  .  Q  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#
#  .  .  .  .  .  .  .  .  .  .  .  .  .  Q  .  .  .  .  .  .
#
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Q  .
#
#  .  .  .  .  .  .  Q  .  .  .  .  .  .  .  .  .  .  .  .  .
#
#  .  .  .  .  .  .  .  .  Q  .  .  .  .  .  .  .  .  .  .  .
#
#  .  .  Q  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Q  .  .  .
#
#  .  Q  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#
#  .  .  .  .  .  .  .  .  .  .  Q  .  .  .  .  .  .  .  .  .
#
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Q  .  .  .  .
#
#  .  .  .  .  .  .  .  .  .  .  .  Q  .  .  .  .  .  .  .  .
#
#  Q  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#
#  .  .  .  Q  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .  .
#
#  .  .  .  .  .  .  .  .  .  .  .  .  Q  .  .  .  .  .  .  .
#
#  .  .  .  .  .  .  .  .  .  .  .  .  .  .  Q  .  .  .  .  .
